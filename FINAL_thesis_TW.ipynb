# %% [markdown]
# Install dependencies

# %%
# !pip install spacy
# install the trained Dutch pipeline, used for tokenizing the corpus
# !python -m spacy download nl_core_news_sm
# !pip install lxml
# clone the repository of OpenDutchWordnet, the dictionary
# !rm -rf OpenDutchWordnet
# !git clone https://github.com/cltl/OpenDutchWordnet.git
# !python setup.py install
# !pip install rdflib
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting nl-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/nl_core_news_sm-3.7.0/nl_core_news_sm-3.7.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from nl-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: nl-core-news-sm
# Successfully installed nl-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('nl_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (5.3.0)
# Cloning into 'OpenDutchWordnet'...
# remote: Enumerating objects: 307, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 307 (delta 0), reused 1 (delta 0), pack-reused 304 (from 1)
# Receiving objects: 100% (307/307), 130.61 MiB | 19.58 MiB/s, done.
# Resolving deltas: 100% (130/130), done.
# Updating files: 100% (167/167), done.
# python3: can't open file '/content/setup.py': [Errno 2] No such file or directory
# Collecting rdflib
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib) (3.2.1)
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: rdflib
# Successfully installed rdflib-7.1.3

# %% [markdown]
# Import all tools

# %%
import xml.etree.ElementTree as ET
# Dutch pipeline for tokenizing the corpus
import spacy
nlp = spacy.load("nl_core_news_sm")
# Lxml to deal with XML-type files
import lxml
# Open Dutch WordNet for dictionary meanings
from OpenDutchWordnet import Wn_grid_parser
odwn = Wn_grid_parser(Wn_grid_parser.odwn)
# BERTje model for contextualized word embeddings
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("GroNLP/bert-base-dutch-cased")
model = AutoModel.from_pretrained("GroNLP/bert-base-dutch-cased")
# tools to compare word embeddings
from sklearn.metrics.pairwise import cosine_similarity
import torch
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/254 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/242k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/437M [00:00<?, ?B/s]
# Some weights of BertModel were not initialized from the model checkpoint at GroNLP/bert-base-dutch-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Function definitions for preprocessing Lassy Small corpus.

# %%
# takes a XML-file and then extracts the plain text sentence from that file
def Lassy_XML_to_text(file):
  # create empty list to add all sentences to
  sents = []
  # read the file
  tree = ET.parse(file)
  # get the root element of the tree, which contains all other elements
  root = tree.getroot()
  # find every <sentence> element and add its text to the list of sentences
  for sent in root.iter('sentence'):
    sents.append(sent.text)
  return sents

# takes a list of strings with XML filenames, returns a text with plain text from these files
def Lassy_filelist_to_text(file_list):
  # create list for all sentences from different files
  all_sentences = []
  # extract the plain text by iterating over these files
  for filename in file_list:
    new_sent = Lassy_XML_to_text(filename)
    for word in new_sent:
      all_sentences.append(word)
  # Join list of all sentences together to form one text.
  one_text = ' '.join(all_sentences)
  return one_text

# %% [markdown]
# Function definitions for retrieving and comparing basic and contextual meaning for lexical units from a corpus of plain text.

# %%
# Function to get basic meanings for all nouns in a tokenized text.
def get_basic_meanings(corpus):
  basic_meanings = {}
  for token in corpus:
    if token.pos_ == "NOUN":
      meanings_num = odwn.lemma_num_senses(token.text, pos='noun')
      if meanings_num >1:
        token_entry = odwn.les_find_le(f"{token.text}-n-1")
        if token_entry:
          token_def = token_entry.get_definition()
          basic_meanings[token] = token_def
  return basic_meanings

# Function to get the contextual embedding of a token using BERTje.
def get_contextual_embedding(LU, sent):
  inputs = tokenizer(sent, return_tensors = "pt", padding = True, truncation = True)
  outputs = model(**inputs)
  tokenized_sentence = tokenizer.tokenize(sent)
  LU_tokens = tokenizer.tokenize(LU.text)
  LU_index = -1
  for i in range(len(tokenized_sentence)-  len(LU_tokens)+1):
    if tokenized_sentence[i:i + len(LU_tokens)] == LU_tokens:
      LU_index = i
      break
  if LU_index == -1:
    raise ValueError(f"Could not find tokens for {LU.text} in the tokenized sentence")
  #get index of token in tokenized input
  # LU_index = inputs.input_ids[0].tolist().index(tokenizer.convert_tokens_to_ids(LU.text))
  #get contextualized embedding
  LU_embedding = outputs.last_hidden_state[0,LU_index, :]
  return LU_embedding

# Function to get the synset embeddings for a token.
def get_synset_embeddings(LU):
  # create list for synsets
  synsets = []
  meanings_num = odwn.lemma_num_senses(LU.text, pos='noun')
  if meanings_num >0:
    for sense_num in range(1,meanings_num +1):
      le = odwn.les_find_le(f"{LU.text}-n-{sense_num}")
      if le:
        synset_text = le.get_definition()
        inputs = tokenizer(synset_text, return_tensors="pt", padding = True, truncation = True)
        outputs = model(**inputs)
        synset_embedding = outputs.last_hidden_state.mean(dim=1)
        synsets.append((le, synset_embedding))
    return synsets

# function that retrieves contextual meanings for noun tokens in a dictionary, using the corpus for context
def get_contextual_meanings(corpus, basic_dict):
  con_meanings = {}
  for token in basic_dict:
    sentence = token.sent.text
    word_embedding = get_contextual_embedding(token, sentence)
    synsets = get_synset_embeddings(token)
    if synsets:
      best_synset = None
      max_similarity = 0
      for le, synset_embedding in synsets:
        similarity = cosine_similarity(word_embedding.detach().numpy().reshape(1,-1), synset_embedding.detach().numpy().reshape(1,-1))[0][0]
        if similarity > max_similarity:
          max_similarity = similarity
          best_synset = le
        if best_synset:
          con_meanings[token] = best_synset.get_definition()
  return con_meanings

def compare_meanings(basic_dict, contextual_dict):
  non_literal_dict = {}
  for word, meaning in basic_dict.items():
    #if word in contextual_dict:
    if meaning != contextual_dict[word]:
      non_literal_dict[word] = (meaning, contextual_dict[word])
  return non_literal_dict

def preprocess(text):
  lower_text = text.lower()
  processed_text = nlp(lower_text)
  no_punct_text = [token for token in processed_text if not token.is_punct]
  no_num_text = [token for token in no_punct_text if not token.is_digit]
  no_mrw_text = [token for token in no_num_text if token.text!="mrw"]
  return no_mrw_text

def MIPVU(corpus):
  processed_corpus = preprocess(corpus)
  bdef = get_basic_meanings(processed_corpus)
  cdef= get_contextual_meanings(processed_corpus, bdef)
  res = compare_meanings(bdef, cdef)
  return res

# %% [markdown]
# Import corpus and preprocess if necessary (for Lassy Small corpus). Then apply MIPVU.

# %%
# take a small set of the corpus, save it as a list of filenames
file_list = ['WR-P-E-E-0000000018.p.1.s.1.xml','WR-P-E-E-0000000018.p.2.s.1.xml','WR-P-E-E-0000000018.p.2.s.2.xml','WR-P-E-E-0000000018.p.2.s.3.xml','WR-P-E-E-0000000018.p.2.s.4.xml','WR-P-E-E-0000000018.p.2.s.5.xml','WR-P-E-E-0000000018.p.3.s.1.xml','WR-P-E-E-0000000018.p.4.s.1.xml','WR-P-E-E-0000000018.p.5.s.1.xml','WR-P-E-E-0000000018.p.6.s.1.xml','WR-P-E-E-0000000018.p.7.s.1.xml','WR-P-E-E-0000000018.p.7.s.2.xml','WR-P-E-E-0000000018.p.7.s.3.xml','WR-P-E-E-0000000018.p.7.s.4.xml','WR-P-E-E-0000000018.p.7.s.5.xml','WR-P-E-E-0000000018.p.7.s.6.xml','WR-P-E-E-0000000018.p.7.s.7.xml','WR-P-E-E-0000000018.p.8.s.1.xml','WR-P-E-E-0000000018.p.8.s.2.xml','WR-P-E-E-0000000018.p.9.s.1.xml','WR-P-E-E-0000000018.p.10.s.1.xml','WR-P-E-E-0000000018.p.10.s.2.xml','WR-P-E-E-0000000018.p.10.s.3.xml','WR-P-E-E-0000000018.p.10.s.4.xml','WR-P-E-E-0000000018.p.10.s.5.xml','WR-P-E-E-0000000018.p.11.s.1.xml','WR-P-E-E-0000000018.p.11.s.2.xml','WR-P-E-E-0000000018.p.12.s.1.xml','WR-P-E-E-0000000018.p.13.s.1.xml','WR-P-E-E-0000000018.p.14.s.1.xml','WR-P-E-E-0000000018.p.14.s.2.xml','WR-P-E-E-0000000018.p.14.s.3.xml','WR-P-E-E-0000000018.p.14.s.4.xml','WR-P-E-E-0000000018.p.14.s.5.xml','WR-P-E-E-0000000018.p.14.s.6.xml','WR-P-E-E-0000000018.p.14.s.7.xml','WR-P-E-E-0000000018.p.15.s.1.xml','WR-P-E-E-0000000018.p.15.s.2.xml']
corpus_Lassy = Lassy_filelist_to_text(file_list)
# make sure the files in the file list together form a text and not more or less.
print(corpus_Lassy)
Lassy_MIPVU = MIPVU(corpus_Lassy)
for word, meaning in Lassy_MIPVU.items():
  print(word)
  print(meaning)
# Out:
# Computers hoeven geen Nederlands te kunnen verstaan " Al geef je programmeurs van vertaalcomputers er nog vijftig jaar bij , de vertaalcomputers zullen er nooit in slagen de perfecte vertaling af te leveren . Daarvoor verloopt de menselijke communicatie te subtiel , te genuanceerd , te rijk . En laat de overheid asjeblief ophouden met belastinggeld uit te geven aan de ontwikkeling van computers die Nederlands moeten verstaan . Er zijn wel zinvoller bestedingen . " - Marc van Oostendorp Lees verder op : http://taalschrift.org/discussie/000087.html U wordt uitgenodigd om te reageren via de reactiemogelijkheid onderaan de column . Vorige maand heeft het Vlaamse taaltechnologiebedrijf Language & Computing ( L&C ) een belangrijk contract kunnen afsluiten met de Amerikaanse overheid voor het leveren van de tools voor het " national patiënt safety network " , dat de bedoeling heeft om verschillende medische informatiebronnen ( met gegevens in natuurlijke taal ) met elkaar te koppelen en beschikbaar te maken voor analyses ; dit alles met de bedoeling op de veiligheid van de patiënten te verhogen . Meer informatie op de nieuwe website van L&C : http://www.landcglobal.com/pages/newsview.php?news_id=82 Sinds 24 juni kunnen vakantiegangers gebruikmaken van een lastminute taalcursus via de telefoon . Wie belt met 06 - 48984808 kan ruim 100 veelgebruikte ' vakantiezinnen ' oefenen in 8 talen : Spaans , Frans , Italiaans , Duits , Engels , Grieks , Turks en Zweeds . De cursist hoort de buitenlandse tekst , herhaalt de zin en kan luisteren naar zijn eigen uitspraak . Het telefoonnummer is een extra dienst van Vakantietaal.nl , een website waar reizigers sinds twee jaar lastminute taalcursussen kunnen downloaden in mp3 of op cd bestellen . Voor het nummer , dat ook vanuit het buitenland bereikbaar is , geldt het normale gesprekstarief . De dienst is geheel spraakgestuurd , dus hands free . Zeg bijvoorbeeld ' Spaans ' en de cursus Spaans begint . De telefonische taalcursus is een gezamenlijk initiatief van Vakantietaal.nl ( www.vakantietaal.nl ) en Group 2000 te Almelo . Group 2000 is al 25 jaar actief op het gebied van interactieve telecommunicatie en spraakherkenning ( www.group2000.nl ) . Tilburg De Faculteit der Letteren van de UvT heeft op korte termijn twee vacatures voor de functie van AIO v / m voor het project ' Interfaces , interacties en het leren van een tweede taal ' vacaturenummer 810.03.07 , voor de volledige werktijd . De te benoemen AiO's zullen werkzaam zijn bij de sectie Taal & Informatica en de sectie Meertaligheid in de Multiculturele Samenleving van de Faculteit der Letteren . Bij de ontwikkeling van computerprogramma's voor het ( taal - ) onderwijs worden combinaties in praktijk gebracht van taalleerinhouden , taalleerstrategieën en leerling-computer interactievormen ( de user interface ) die in wisselende en vaak beperkte mate gebaseerd zijn op theoretische inzichten of geëxpliciteerde aannamen ( zowel op het terrein van het taalleren als van de informatica ) met betrekking tot de optimaliteit van de samenstellende delen van de gekozen combinatie . In het project ' Interfaces , interacties en het leren van een tweede taal ' wordt kennis van onderwijs- en taalleerprocessen in NT2-onderwijs gecombineerd met kennis van mens-computer interactie om te onderzoeken waar de ' gemiste kansen ' zitten in het huidige aanbod , en een bijdrage te leveren aan het opvullen van de lacunes middels de ontwikkeling van empirisch onderbouwde modellen van effectief adaptief onderwijs . Het project omvat twee deelprojecten : " Constructieve analyse van computerprogramma's voor NT2-onderwijs op maat " , en " Adaptieve structurering van ( digitaal ) lesmateriaal voor ( tweede - ) taalonderwijs " , die nauw met elkaar samenhangen . Zie voor nadere informatie : http://www.uvt.nl/personeel/vacatures/extern/8100307.html . Solliciteren kan tot uiterlijk 28 augustus 2003 . Amsterdam Voor het Amsterdam Center for Language and Communication ( ACLC ) zo ...
# ontwikkeling
# ('groei', 'één v.d. gebeurtenissen in een reeks')
# contract
# ('schriftelijke overeenkomst', 'speelbeurt in bridge')
# bedoeling
# ('strekking', 'voornemen')
# bedoeling
# ('strekking', 'voornemen')
# veiligheid
# ('het veilig zijn', 'iets dat beschermt tegen schade, verlies')
# zin
# ('zintuig', 'gestructureerde reeks woorden')
# uitspraak
# ('wijze van uitspreken', 'dat wat gezegd is')
# dienst
# ('het uitvoeren van werkzaamheden', 'werkzaamheden van de dienst als afdeling of instellingen')
# nummer
# ('plaatsaanduider', 'exemplaar van een reeks')
# dienst
# ('het uitvoeren van werkzaamheden', 'eredienst in de kerk')
# gebied
# ('regio', '(geestelijk) domein')
# termijn
# ('periode met vastgesteld einde', 'deel v.e. te betalen schuld')
# functie
# ('taak of ambt', 'werking of verrichting')
# project
# ('geheel van geplande werkzaamheden', 'onderwerp voor een werkstuk')
# sectie
# ('onderdeel van een groter geheel', 'het opensnijden v.e. lijk')
# sectie
# ('onderdeel van een groter geheel', 'het opensnijden v.e. lijk')
# samenleving
# ('maatschappij', 'het met elkaar samenleven')
# ontwikkeling
# ('groei', 'één v.d. gebeurtenissen in een reeks')
# terrein
# ('gebied', 'onderwerp van gesprek/gedachten')
# informatica
# ('computerkunde', 'vrouwelijke computerdeskundige')
# betrekking
# ('werk', 'verband')
# combinatie
# ('samenvoeging', 'reeks zetten in het schaak- of damspel')
# project
# ('geheel van geplande werkzaamheden', 'onderwerp voor een werkstuk')
# kennis
# ('bekende', 'wetenschap')
# kennis
# ('bekende', 'wetenschap')
# aanbod
# ('het aanbieden van iets aan iemand', 'tekst of voorstel waarmee men iets aanbiedt')
# bijdrage
# ('financiële inbreng', 'immateriële inbreng')
# ontwikkeling
# ('groei', 'één v.d. gebeurtenissen in een reeks')
# project
# ('geheel van geplande werkzaamheden', 'onderwerp voor een werkstuk')
# analyse
# ('onderzoek naar de aard van iets', 'therapeutische behandelingswijze')
# maat
# ('uitdrukking van inhoud of grootte', 'indeling in muziek die het ritme bepaalt')
# uiterlijk
# ('uitwendige gedaante', 'wat naar buiten zichtbaar is')
# instituut
# ('onderzoeksinstelling', 'maatschappelijke instelling')
# plaats
# ('ruimte voor iets', 'plaats voor een werknemer in het arbeidsproces')
# analyse
# ('onderzoek naar de aard van iets', 'therapeutische behandelingswijze')
# gebied
# ('regio', '(geestelijk) domein')
# typologie
# ('indeling obv. eigenschappen', 'leer in de theologie')
# element
# ('bestanddeel v.d. stoffelijke wereld', 'toestel waarin door chemische werking elektriciteit wordt opgewekt')
# uiterlijk
# ('uitwendige gedaante', 'wat naar buiten zichtbaar is')

# %% [markdown]
# Try it out with some sample sentences

# %%
test = 'De student moest een berg huiswerk maken in een weekend.'
haha = MIPVU(test)
for word, meaning in haha.items():
  print(word)
  print(meaning)

# %% [markdown]
# Evaluation with Bruggen corpus.

# %%
# read the file and preprocess the text
Bruggen_file = open('Bruggen (2024) bijlage 1.txt', 'r')
Bruggen_corpus = Bruggen_file.read()
Bruggen_MIPVU = MIPVU(Bruggen_corpus)

# %%
Bruggen_parsed = preprocess(Bruggen_corpus)

# %%
eval_Bruggen = get_basic_meanings(Bruggen_parsed)

# %%
for word, meaning in eval_Bruggen.items():
  print(f"word: {word}, meaning: {meaning}")
# Out:
# word: voorzitter, meaning: leider v.e. vergadering
# word: wet, meaning: door de overheid vastgestelde regel
# word: uiterlijk, meaning: uitwendige gedaante
# word: kabinet, meaning: kast
# word: richting, meaning: kant waarnaar iets neigt of gaat
# word: jaar, meaning: 12 maanden
# word: politiek, meaning: regeer- en bestuursbeleid v.e. land
# word: kritiek, meaning: meningsuiting mbt. fouten of gebreken
# word: raad, meaning: advies
# word: praktijk, meaning: werkkring v.e. dokter, advocaat enz.
# word: wet, meaning: door de overheid vastgestelde regel
# word: toekomst, meaning: tijd die nog moet komen
# word: land, meaning: grond boven water
# word: begin, meaning: start
# word: begin, meaning: start
# word: discussie, meaning: bespreking v.e. probleem
# word: staat, meaning: toestand
# word: amendement, meaning: voorstel voor wijziging in wet
# word: kamer, meaning: vertrek in een gebouw of huis
# word: wet, meaning: door de overheid vastgestelde regel
# word: amendement, meaning: voorstel voor wijziging in wet
# word: opgave, meaning: vraagstuk
# word: fase, meaning: trap in een ontwikkeling
# word: ruimte, meaning: plaats
# word: overleg, meaning: inzicht
# word: wet, meaning: door de overheid vastgestelde regel
# word: oplossing, meaning: antwoord op vraag of probleem
# word: systematiek, meaning: doordachte ordening
# word: systematiek, meaning: doordachte ordening
# word: aantal, meaning: hoeveelheid
# word: verplichting, meaning: iets waartoe je verplicht bent
# word: wet, meaning: door de overheid vastgestelde regel
# word: fractie, meaning: (zeer klein) onderdeel van iets
# word: aantal, meaning: hoeveelheid
# word: meerderheid, meaning: (groep met) grootste aantal
# word: slag, meaning: fysieke klap
# word: voorzitter, meaning: leider v.e. vergadering
# word: termijn, meaning: periode met vastgesteld einde
# word: kabinet, meaning: kast
# word: wet, meaning: door de overheid vastgestelde regel
# word: verkiezingen, meaning:
# word: wet, meaning: door de overheid vastgestelde regel
# word: verantwoordelijkheid, meaning: aansprakelijkheid
# word: kamer, meaning: vertrek in een gebouw of huis
# word: uiterlijk, meaning: uitwendige gedaante
# word: taak, meaning: opdracht
# word: tijd, meaning: aaneenschakeling van momenten
# word: onzekerheid, meaning: twijfel
# word: week, meaning: periode van zeven aaneengesloten dagen
# word: weer, meaning: atmosferische gesteldheid
# word: urgentie, meaning: geval dat grote spoed vereist
# word: dimensie, meaning: afmeting
# word: kabinet, meaning: kast
# word: jaar, meaning: 12 maanden
# word: land, meaning: grond boven water
# word: programma, meaning: opsomming van gebeurtenissen
# word: land, meaning: grond boven water
# word: kwart, meaning: vierde deel
# word: geval, meaning: casus, voorbeeld
# word: nood, meaning: gevaar
# word: week, meaning: periode van zeven aaneengesloten dagen
# word: nood, meaning: gevaar
# word: inspectie, meaning: toezicht
# word: oplossing, meaning: antwoord op vraag of probleem
# word: zicht, meaning: vermogen tot zien
# word: aanpak, meaning: methode
# word: onderwerp, meaning: dat waarover men spreekt of schrijft
# word: kamer, meaning: vertrek in een gebouw of huis
# word: inzicht, meaning: het begrijpen
# word: jaar, meaning: 12 maanden
# word: duidelijkheid, meaning: het helder zijn
# word: perspectief, meaning: vooruitzicht
# word: moment, meaning: ogenblik
# word: verbetering, meaning: vooruitgang
# word: amendement, meaning: voorstel voor wijziging in wet
# word: geval, meaning: casus, voorbeeld
# word: aandeel, meaning: bewijs van investering in een bedrijf
# word: jaar, meaning: 12 maanden
# word: meerderheid, meaning: (groep met) grootste aantal
# word: voorzitter, meaning: leider v.e. vergadering
# word: verandering, meaning: wijziging
# word: aantal, meaning: hoeveelheid
# word: wetgeving, meaning: bestaande wetten
# word: tijd, meaning: aaneenschakeling van momenten
# word: verantwoordelijkheid, meaning: aansprakelijkheid
# word: stuk, meaning: deel
# word: amendement, meaning: voorstel voor wijziging in wet
# word: realiteit, meaning: al wat bestaat
# word: kamer, meaning: vertrek in een gebouw of huis
# word: meerderheid, meaning: (groep met) grootste aantal
# word: geval, meaning: casus, voorbeeld
# word: amendement, meaning: voorstel voor wijziging in wet
# word: meerderheid, meaning: (groep met) grootste aantal
# word: amendement, meaning: voorstel voor wijziging in wet
# word: wet, meaning: door de overheid vastgestelde regel
# word: amendement, meaning: voorstel voor wijziging in wet
# word: meerderheid, meaning: (groep met) grootste aantal
# word: steun, meaning: ondersteuning
# word: geval, meaning: casus, voorbeeld
# word: benaming, meaning: naamgeving
# word: geval, meaning: casus, voorbeeld
# word: jaar, meaning: 12 maanden
# word: kabinet, meaning: kast
# word: opgave, meaning: vraagstuk
# word: wet, meaning: door de overheid vastgestelde regel
# word: verdeling, meaning: het verdelen
# word: wet, meaning: door de overheid vastgestelde regel
# word: financiering, meaning: het verstrekken van geld
# word: systeem, meaning: geordende eenheid
# word: bed, meaning: slaapmeubel
# word: paar, meaning: twee bij elkaar horende dingen
# word: weg, meaning: (verharde) strook grond voor verkeer
# word: kabinet, meaning: kast
# word: land, meaning: grond boven water
# word: wijze, meaning: manier
# word: financiering, meaning: het verstrekken van geld
# word: wet, meaning: door de overheid vastgestelde regel
# word: mogelijkheid, meaning: iets dat kan gebeuren
# word: ontwikkeling, meaning: groei
# word: zorg, meaning: behartiging
# word: kwaliteit, meaning: waarde of geschiktheid
# word: voorzitter, meaning: leider v.e. vergadering
# word: aandacht, meaning: attentie
# word: probleem, meaning: moeilijkheid
# word: thuisland, meaning: gebied in Zuid-Afrika
# word: aantal, meaning: hoeveelheid
# word: bus, meaning: autobus
# word: land, meaning: grond boven water
# word: gemis, meaning: het niet bezitten van iets
# word: samenleving, meaning: maatschappij
# word: werknemer, meaning: iemand die ergens in loondienst is
# word: week, meaning: periode van zeven aaneengesloten dagen
# word: risico, meaning: kans op iets negatiefs
# word: motie, meaning: bijkomend voorstel aan een vergadering
# word: kabinet, meaning: kast
# word: perspectief, meaning: vooruitzicht
# word: wetgeving, meaning: bestaande wetten
# word: voorzitter, meaning: leider v.e. vergadering
# word: onderwerp, meaning: dat waarover men spreekt of schrijft
# word: jaar, meaning: 12 maanden
# word: beeld, meaning: beeldhouwwerk
# word: aantal, meaning: hoeveelheid
# word: oorzaak, meaning: dat waardoor iets gebeurt
# word: crisis, meaning: kritieke situatie
# word: jaar, meaning: 12 maanden
# word: herinnering, meaning: iets dat je je herinnert
# word: raad, meaning: advies
# word: bestuur, meaning: het leiden of regelen
# word: overheid, meaning: autoriteit, administratieve eenheid
# word: oorzaak, meaning: dat waardoor iets gebeurt
# word: gebrek, meaning: onvoldoende aanwezigheid
# word: flexibiliteit, meaning: lenigheid van lichaam, spieren
# word: systeem, meaning: geordende eenheid
# word: instituut, meaning: onderzoeksinstelling
# word: veiligheid, meaning: het veilig zijn
# word: capaciteit, meaning: vermogen
# word: afdeling, meaning: onderdeel v.e. instelling
# word: identificatie, meaning: gevoel gelijk te zijn met een ander
# word: registratie, meaning: ambtelijke vastlegging v.e. gegeven
# word: crisis, meaning: kritieke situatie
# word: heer, meaning: man
# word: voorzitter, meaning: leider v.e. vergadering
# word: jaar, meaning: 12 maanden
# word: heer, meaning: man
# word: voorzitter, meaning: leider v.e. vergadering
# word: punt, meaning: kleine stip
# word: werk, meaning: uitvoering van taken, opdrachten
# word: kabinet, meaning: kast
# word: werk, meaning: uitvoering van taken, opdrachten
# word: heden, meaning: het nu
# word: gevoel, meaning: zintuig v.h. voelen
# word: totaal, meaning: optelling van getallen of bedragen
# word: politiek, meaning: regeer- en bestuursbeleid v.e. land
# word: land, meaning: grond boven water
# word: feit, meaning: wat werkelijk zo is (gebeurd)
# word: plek, meaning: (punt in de) ruimte
# word: stijging, meaning: het omhooggaan v.h. niveau
# word: aantal, meaning: hoeveelheid
# word: vraag, meaning: verzoek om informatie
# word: zicht, meaning: vermogen tot zien
# word: oplossing, meaning: antwoord op vraag of probleem
# word: groep, meaning: verzameling bijeenhorende personen of zaken
# word: groep, meaning: verzameling bijeenhorende personen of zaken
# word: groep, meaning: verzameling bijeenhorende personen of zaken
# word: land, meaning: grond boven water
# word: moment, meaning: ogenblik
# word: punt, meaning: kleine stip
# word: reactie, meaning: door andere actie opgeroepen actie van personen
# word: kabinet, meaning: kast
# word: jaar, meaning: 12 maanden
# word: geld, meaning: algemeen betaalmiddel
# word: beschikking, meaning: macht om te beschikken
# word: moment, meaning: ogenblik
# word: nieuws, meaning: nieuwe informatie
# word: probleem, meaning: moeilijkheid
# word: registratie, meaning: ambtelijke vastlegging v.e. gegeven
# word: week, meaning: periode van zeven aaneengesloten dagen
# word: geval, meaning: casus, voorbeeld
# word: registratie, meaning: ambtelijke vastlegging v.e. gegeven
# word: voorzitter, meaning: leider v.e. vergadering
# word: feit, meaning: wat werkelijk zo is (gebeurd)
# word: gemeente, meaning: zelfstandig onderdeel v.e. staat
# word: voorzitter, meaning: leider v.e. vergadering
# word: week, meaning: periode van zeven aaneengesloten dagen
# word: vraag, meaning: verzoek om informatie
# word: plek, meaning: (punt in de) ruimte
# word: voorzitter, meaning: leider v.e. vergadering
# word: chaos, meaning: wanorde
# word: draagvlak, meaning: vlak waarop iets steunt
# word: land, meaning: grond boven water
# word: uitsluitsel, meaning: opheldering
# word: overheid, meaning: autoriteit, administratieve eenheid
# word: rest, meaning: overblijfsel
# word: overheid, meaning: autoriteit, administratieve eenheid
# word: voorwaarde, meaning: dat waaraan iets moet voldoen
# word: meerderheid, meaning: (groep met) grootste aantal
# word: gehoor, meaning: het horen zelf
# word: kabinet, meaning: kast
# word: meerderheid, meaning: (groep met) grootste aantal
# word: kamer, meaning: vertrek in een gebouw of huis
# word: wet, meaning: door de overheid vastgestelde regel
# word: kritiek, meaning: meningsuiting mbt. fouten of gebreken
# word: reden, meaning: zaken die mensen ergens toe brengen
# word: fractie, meaning: (zeer klein) onderdeel van iets
# word: wet, meaning: door de overheid vastgestelde regel
# word: meerderheid, meaning: (groep met) grootste aantal
# word: slot, meaning: sluitmechanisme
# word: dag, meaning: periode per 24 uur waarin het licht is
# word: nacht, meaning: tijd v.d. dag dat het donker is
# word: steentje, meaning: diamantnijverheid
# word: zorg, meaning: behartiging
# word: werk, meaning: uitvoering van taken, opdrachten
# word: kamer, meaning: vertrek in een gebouw of huis
# word: verschil, meaning: punt waarop geen overeenkomst is
# word: leven, meaning: het bestaan van organismen
# word: oorlog, meaning: gevecht tussen landen of volkeren
# word: vervolging, meaning: achtervolging met kwaad in de zin
# word: voorzitter, meaning: leider v.e. vergadering
# word: voorzitter, meaning: leider v.e. vergadering
# word: richting, meaning: kant waarnaar iets neigt of gaat
# word: ding, meaning: voorwerp
# word: fractie, meaning: (zeer klein) onderdeel van iets
# word: amendement, meaning: voorstel voor wijziging in wet
# word: stuk, meaning: deel
# word: oordeel, meaning: manier waarop je over iets denkt
# word: kamer, meaning: vertrek in een gebouw of huis
# word: amendement, meaning: voorstel voor wijziging in wet
# word: wet, meaning: door de overheid vastgestelde regel
# word: fractie, meaning: (zeer klein) onderdeel van iets
# word: notie, meaning: besef
# word: manier, meaning: wijze
# word: wet, meaning: door de overheid vastgestelde regel
# word: wet, meaning: door de overheid vastgestelde regel
# word: voorzitter, meaning: leider v.e. vergadering
# word: discussie, meaning: bespreking v.e. probleem
# word: beetje, meaning: kleine hoeveelheid
# word: ongemak, meaning: hinder
# word: spreiding, meaning: gelijkmatige verdeling
# word: aantal, meaning: hoeveelheid
# word: wet, meaning: door de overheid vastgestelde regel
# word: discussie, meaning: bespreking v.e. probleem
# word: vraagstuk, meaning: complex probleem
# word: heer, meaning: man
# word: ceder, meaning:
# word: zorg, meaning: behartiging
# word: wet, meaning: door de overheid vastgestelde regel
# word: beetje, meaning: kleine hoeveelheid
# word: uitvoering, meaning: het realiseren van iets
# word: amendement, meaning: voorstel voor wijziging in wet
# word: stuk, meaning: deel
# word: raad, meaning: advies
# word: wet, meaning: door de overheid vastgestelde regel
# word: fractie, meaning: (zeer klein) onderdeel van iets
# word: wet, meaning: door de overheid vastgestelde regel
# word: keer, meaning: moment dat iets gebeurt
# word: westen, meaning: één v.d. vier windstreken
# word: raad, meaning: advies
# word: manier, meaning: wijze
# word: last, meaning: vracht die je meedraagt

# %%
hi = ' '
print(f"Noun {hi:10} Basic meaning {hi:10} Contextual meaning {hi:10}")

for word, meaning in Bruggen_MIPVU.items():
  print(f"hep {word.text:10} haha {meaning:10} haha {meaning:10} de")
# Out:
# Noun            Basic meaning            Contextual meaning
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-b341f80b2d5c> in <cell line: 0>()
#       3
#       4 for word, meaning in Bruggen_MIPVU.items():
# ----> 5   print(f"hep {word.text:10} haha {meaning:10} haha {meaning:10} de")
#
# TypeError: unsupported format string passed to tuple.__format__

# %%
# Perform MIPVU on the corpus.
bdef = get_basic_meanings(processed_Bruggen)
cdef= get_contextual_meanings(processed_Bruggen)
result_Bruggen = compare_meanings(bdef, cdef)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-b3a801f45964> in <cell line: 0>()
#       1 # Perform MIPVU on the corpus.
#       2 bdef = get_basic_meanings(processed_Bruggen)
# ----> 3 cdef= get_contextual_meanings(processed_Bruggen)
#       4 result_Bruggen = compare_meanings(bdef, cdef)
#
# <ipython-input-5-b52987d14162> in get_contextual_meanings(corpus)
#      52     sentence = token.sent.text
#      53     word_embedding = get_contextual_embedding(token, sentence)
# ---> 54     synsets = get_synset_embeddings(token)
#      55     if synsets:
#      56       best_synset = None
#
# <ipython-input-5-b52987d14162> in get_synset_embeddings(LU)
#      35   # create list for synsets
#      36   synsets = []
# ---> 37   meanings_num = odwn.lemma_num_senses(LU.text, pos='noun')
#      38   if meanings_num >0:
#      39     for sense_num in range(1,meanings_num +1):
#
# /content/OpenDutchWordnet/lemma.py in lemma_num_senses(self, lemma, pos)
#      76         @return: number of senses
#      77         '''
# ---> 78         return len(self.lemma_get_generator(lemma, pos))
#      79
#      80
#
# /content/OpenDutchWordnet/lemma.py in lemma_get_generator(self, lemma, pos)
#      47         les = []
#      48
# ---> 49         for le_obj in self.les_get_generator():
#      50             can_lemma = le_obj.get_lemma()
#      51
#
# /content/OpenDutchWordnet/les.py in les_get_generator(self, mw)
#      28         for le_el in self.doc.iterfind(self.path_to_le_els):
#      29             instance = Le(le_el,self.lexicon_el)
# ---> 30             le_id    = instance.get_id()
#      31             if mw:
#      32                 yield instance
#
# /content/OpenDutchWordnet/le.py in get_id(self)
#      26         :return: identifier of lexical entry
#      27         '''
# ---> 28         return self.le_el.get("id")
#      29
#      30     def get_lemma(self):
#
# KeyboardInterrupt:

# %%
# For word in dictionary, check if token has (MRW) behind it in the original corpus.
# OR: for all words with (MRW) after it in Bruggen's corpus, check if the result_Bruggen contains the word.
# So, function that searches for (MRW) and retrieves the instance before that and checks dictionary membership.
def Evaluate_Bruggen(res_dict, p_corpus):
  correctly_positive = 0
  for token in p_corpus:
    if token.text == "(MRW)":
      #find previous token
      if prev.text in res_dict:
        correctly_positive ++
        print(f"{prev.text} was correctly detected with meanings {res_dict[pre.text]}")
  return correctly_positive
